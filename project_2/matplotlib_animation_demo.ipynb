# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib notebook

# generate 4 random variables from the random, gamma, exponential, and uniform distributions
x1 = np.random.normal(-2.5, 1, 10000)
x2 = np.random.gamma(2, 1.5, 10000)
x3 = np.random.exponential(2, 10000)+7
x4 = np.random.uniform(14,20, 10000)

# plot the histograms
plt.figure(figsize=(9,3))
plt.hist(x1, normed=True, bins=20, alpha=0.5)
plt.hist(x2, normed=True, bins=20, alpha=0.5)
plt.hist(x3, normed=True, bins=20, alpha=0.5)
plt.hist(x4, normed=True, bins=20, alpha=0.5);
plt.axis([-7,21,0,0.6])

plt.text(x1.mean()-1.5, 0.5, 'x1\nNormal')
plt.text(x2.mean()-1.5, 0.5, 'x2\nGamma')
plt.text(x3.mean()-1.5, 0.5, 'x3\nExponential')
plt.text(x4.mean()-1.5, 0.5, 'x4\nUniform')
# Out:
# <img src="data:image/png;base64,...">

# %%
fig, ((ax1,ax2), (ax3,ax4)) = plt.subplots(2, 2, sharex=False, sharey=False)
#fig.set_size_inches(6,4)

axes = [ax1,ax2,ax3,ax4]

# generate 4 random variables from the random, gamma, exponential, and uniform distributions
x1 = np.random.normal(-2.5, 1, 10000)
x2 = np.random.gamma(2, 1.5, 10000)
x3 = np.random.exponential(2, 10000)+7
x4 = np.random.uniform(14,20, 10000)

sample = [x1, x2, x3, x4]

# plot the histograms
for ax, data in zip(axes, sample): 
    ax.hist(data, normed=True, bins=20, alpha=0.5)
    ax.set_xlim(-7, 21)
    ax.set_ylim(0,0.6)
# Out:
# <img src="data:image/png;base64,...">

# %%
import matplotlib.animation as animation
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib notebook

# create the function that will do the plotting, 
# where curr is the current frame
x1 = np.random.normal(-2.5, 1, 100)
x2 = np.random.gamma(2, 1.5, 100)
x3 = np.random.exponential(2, 100)+7
x4 = np.random.uniform(14,20, 100)

#for n_size in range(100,1000):
def update(curr):
    
    # curr starts from 0
    #step = curr ** 10
    
    if curr == 100:
        a.event_source.stop()
           
    print (curr)
    ax1 = fig.add_subplot(2,2,1)
    ax2 = fig.add_subplot(2,2,2)
    ax3 = fig.add_subplot(2,2,3)
    ax4 = fig.add_subplot(2,2,4)
    
    ax1.cla(); ax2.cla(); ax3.cla(); ax4.cla();
    
    bins = np.arange(-8, 20, 0.5)
    axes = [ax1,ax2,ax3,ax4]
    
    for ax in axes:
        ax.set_xlim(-8, 20)
        ax.set_ylim(0,1)
    
    ax1.hist(x1[:curr], normed=True, bins=bins, color='blue')
    ax2.hist(x2[:curr], normed=True, bins=bins, color='blue')
    ax3.hist(x3[:curr], normed=True, bins=bins, color='blue')
    ax4.hist(x4[:curr], normed=True, bins=bins, color='blue')
    
    #ax3.hist(x3[:curr], normed=True, bins=bins)
    #ax4.hist(x4[:curr], normed=True, bins=bins)
    ax1.annotate('n = {}'.format(curr), [10,0.85])
    ax2.annotate('n = {}'.format(curr), [10,0.85])
    ax3.annotate('n = {}'.format(curr), [10,0.85])
    ax4.annotate('n = {}'.format(curr), [10,0.85])
    
    #curr = curr+10
    
##def onClick(event):
#   global pause
#    pause ^= True

step_list = np.arange(0,110,2)

# %%
from matplotlib.widgets import Slider, Button, RadioButtons

fig = plt.figure()


#fig.canvas.mpl_connect('button_press_event', onClick)
#sfreq = Slider(axfreq, 'Freq', 0.1, 30.0, valinit=f0, valstep=delta_f)
# samp = Slider(axamp, 'Amp', 0.1, 10.0, valinit=a0)

a = animation.FuncAnimation(fig, update, 
                            frames = step_list, interval=50)
# Out:
# <img src="data:image/png;base64,...">
